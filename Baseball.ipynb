# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ball=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
ball.head(5)
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
ball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
ball.shape
# Out:
# (30, 17)

# %%
ball.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
ball.W.unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
import seaborn as sns
sns.distplot(ball.W)
sns.histplot(ball.W)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
for i in ball.columns:
    sns.distplot(ball[i])
    plt.show()

# %%
ball.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(ball.isnull())
# Out:
# <AxesSubplot:>

# %%
ball.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
ball.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))
sns.heatmap(ball.corr(),annot=True,linecolor='white',linewidths=.25)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot('H','W',data=ball)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.scatterplot('AB','W',data=ball)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.scatterplot('3B','W',data=ball)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
sns.scatterplot('2B','W',data=ball)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
sns.scatterplot('HR','W',data=ball)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
sns.scatterplot('BB','W',data=ball)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
sns.scatterplot('SO','W',data=ball)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %%
sns.scatterplot('RA','W',data=ball)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
sns.scatterplot('ER','W',data=ball)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
sns.scatterplot('ERA','W',data=ball)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
sns.scatterplot('CG','W',data=ball)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
sns.scatterplot('SHO','W',data=ball)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
sns.scatterplot('SV','W',data=ball)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %% [markdown]
# # Conclusion: features some are very low correlated with target variable and some are highly negative correlated.

# %%
ball.describe().T
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ...

# %%
ball.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
ball=ball[[ 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
       'ERA', 'CG', 'SHO', 'SV', 'E','W']]

# %%
ball.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E   W
# 0   88  95
# 1   86  83
# 2   79  81
# 3  101  76
# 4   86  74

# %% [markdown]
# # Input features: Runs(R), At Bats(AB), Hits(H), Doubles(2B), Triples(3B), Homeruns(HR), Walks(BB), Strikeouts(SO), Stolen Bases(SB),Runs Allowed(RA),Earned Runs(ER), Earned Run Average (ERA), Shutouts(SHO), Saves(SV), Complete Games and Errors(E)
#
# Output: Number of predicted wins (W)

# %%
sns.scatterplot('R','W',hue='AB',data=ball)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %% [markdown]
# # Unique values

# %%
for i in ball.columns:
    ball[i].nunique()
    print("unique values of feature ",i, '= ',ball[i].nunique())
ball.CG.unique()
# Out:
# unique values of feature  R =  28
# unique values of feature  AB =  29
# unique values of feature  H =  29
# unique values of feature  2B =  22
# unique values of feature  3B =  23
# unique values of feature  HR =  27
# unique values of feature  BB =  29
# unique values of feature  SO =  29
# unique values of feature  SB =  27
# unique values of feature  RA =  30
# unique values of feature  ER =  30
# unique values of feature  ERA =  30
# unique values of feature  CG =  9
# unique values of feature  SHO =  12
# unique values of feature  SV =  20
# unique values of feature  E =  21
# unique values of feature  W =  24
# array([ 2, 11,  7,  3,  0,  1,  5,  6,  4], dtype=int64)

# %%
sns.scatterplot('R','W',size='CG',data=ball)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.scatterplot('CG','W',data=ball)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
sns.scatterplot('ER', 'RA', hue='ERA',data=ball)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='RA'>

# %% [markdown]
# # VIF to find multicolinearity

# %%
v= ball.drop('W', axis=1)
v.head(5)
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
scaled= sc.fit_transform(v)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
VIF= pd.DataFrame()
VIF['features']=v.columns

# %%
VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]

# %%
VIF
# Out:
#    features          vif
# 0         R    11.522370
# 1        AB    13.311532
# 2         H    10.070668
# 3        2B     4.019297
# 4        3B     3.294146
# 5        HR    10.079902
# 6        BB     3.806098
# 7        SO     2.652401
# 8        SB     2.102684
# 9        RA   191.839155
# 10       ER  1680.387145
# 11      ERA  1222.722240
# 12       CG     3.059904
# 13      SHO     3.654331
# 14       SV     5.798850
# 15        E     2.186219

# %% [markdown]
# # Many features have more than 5 VIF.Delete feature 'ER'

# %%
v= ball.drop(['W','ER'], axis=1)

# %%
v.head(5)
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ERA  CG  SHO  SV    E
# 0  724  5575  1497  300  42  139  383   973  104  641  3.73   2    8  56   88
# 1  696  5467  1349  277  44  156  439  1264   70  700  4.07   2   12  45   86
# 2  669  5439  1395  303  29  141  533  1157   86  640  3.67  11   10  38   79
# 3  622  5533  1381  260  27  136  404  1231   68  701  3.98   7    9  37  101
# 4  689  5605  1515  289  49  151  455  1259   83  803  4.64   7   12  35   86

# %%
scaled=sc.fit_transform(v)

# %%
VIF2= pd.DataFrame()
VIF2['features']=v.columns

# %%
VIF2['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]

# %%
VIF2
# Out:
#    features         vif
# 0         R   11.158733
# 1        AB    5.863764
# 2         H    9.628749
# 3        2B    3.786446
# 4        3B    3.293109
# 5        HR    9.057309
# 6        BB    3.791451
# 7        SO    2.607389
# 8        SB    1.849280
# 9        RA  122.133235
# 10      ERA  119.328698
# 11       CG    2.741188
# 12      SHO    3.410561
# 13       SV    3.203815
# 14        E    2.107345

# %%
v= ball.drop(['W','ER','RA'], axis=1)

# %%
scaled=sc.fit_transform(v)

# %%
VIF3= pd.DataFrame()
VIF3['features']=v.columns

# %%
VIF3['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]

# %%
VIF3
# Out:
#    features        vif
# 0         R  10.987898
# 1        AB   4.399954
# 2         H   8.941874
# 3        2B   3.729413
# 4        3B   3.142717
# 5        HR   7.882841
# 6        BB   3.468244
# 7        SO   2.155496
# 8        SB   1.819823
# 9       ERA   4.951981
# 10       CG   2.723370
# 11      SHO   3.227759
# 12       SV   2.948133
# 13        E   2.040676

# %%
plt.figure(figsize=(12,10))
sns.heatmap(v.corr(), annot=True,linecolor='black', linewidths=.25)
# Out:
# <AxesSubplot:>

# %%
# All highly correlated features have been removed now.

# %%
v.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # OUTLIERS

# %%
for i in v.columns:
    sns.boxplot(v[i])
    plt.show()

# %%
v.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO',
#        'SV', 'E'],
#       dtype='object')

# %% [markdown]
# # Outliers are in upper range of features R , ERA , SHO , SV , E , lets handle them

# %%
IQR= ball['R'].quantile(.75)-ball['R'].quantile(.25)
IQR
upper= ball['R'].quantile(.75) +( 1.5 * IQR)
upper
# Out:
# 818.75

# %%
v['R']= np.where(v['R']>upper,upper,v['R'])

# %%
IQR= ball['ERA'].quantile(.75)-ball['R'].quantile(.25)
IQR
upper= ball['ERA'].quantile(.75) +( 1.5 * IQR)
upper
# Out:
# -966.3249999999999

# %%
v['ERA']= np.where(v['ERA']>upper,upper,v['ERA'])

# %%
IQR= ball['SHO'].quantile(.75)-ball['SHO'].quantile(.25)
IQR
upper= ball['SHO'].quantile(.75) +( 1.5 * IQR)
upper
v['SHO']= np.where(v['SHO']>upper,upper,v['SHO'])

# %%
IQR= ball['SV'].quantile(.75)-ball['SV'].quantile(.25)
IQR
upper= ball['SV'].quantile(.75) +( 1.5 * IQR)
upper
v['SV']= np.where(v['SV']>upper,upper,v['SV'])

# %%
IQR= ball['E'].quantile(.75)-ball['E'].quantile(.25)
IQR
upper= ball['E'].quantile(.75) +( 1.5 * IQR)
upper
v['E']= np.where(v['E']>upper,upper,v['E'])

# %%
v.skew()
# Out:
# R      0.284282
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# ERA    0.000000
# CG     0.736845
# SHO    0.218030
# SV     0.612333
# E      0.504019
# dtype: float64

# %% [markdown]
# # Transformation

# %%
from sklearn.preprocessing import power_transform
transformed=power_transform(v)
transformed=pd.DataFrame(transformed)
transformed.columns=v.columns
transformed.skew()
# Out:
# R     -0.000604
# AB     0.090410
# H      0.000000
# 2B    -0.035315
# 3B    -0.072933
# HR    -0.000065
# BB    -0.007760
# SO     0.041170
# SB    -0.010455
# ERA    0.000000
# CG    -0.059785
# SHO   -0.017889
# SV     0.001270
# E      0.032939
# dtype: float64

# %%
transformed.head(5)
# Out:
#           R        AB             H        2B        3B        HR        BB  \
# 0  0.779189  0.858727  4.996004e-16  1.477685  1.033103 -0.764626 -1.610915
# 1  0.242379 -0.701451 -3.053113e-16  0.084269  1.203320 -0.158581 -0.502749
# 2 -0.298832 -1.126097  0.000000e+00  1.670782 -0.160270 -0.689676  1.128294
# 3 -1.302405  0.267369 -8.326673e-17 -0.848600 -0.360521 -0.879049 -1.181207
# 4  0.104367  1.267645  5.828671e-16  0.792183  1.616444 -0.329850 -0.206771
#
#          SO        SB   ERA        CG       SHO        SV         E
# 0 -2.569896  0.939708 -16.0 -0.359844 -0.827928  1.564693 -0.357505
# 1  0.134913 -0.539693 -16.0 -0.359844  0.258244  0.361185 -0.560947
# 2 -0.901254  0.211956 -16.0  1.993513 -0.272431 -0.611107 -1.355876
# 3 -0.189628 -0.642564 -16.0  1.220103 -0.546703 -0.767843  0.764697
# 4  0.085459  0.079629 -16.0  1.220103  0.258244 -1.097417 -0.560947

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(transformed)

# %%
X= scaled
Y=ball['W']

# %%
X.shape
# Out:
# (30, 14)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
LR= LinearRegression()

# %%
LR=LinearRegression()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,random_state=40,test_size=0.25)

# %%
for i in range(0,200):
    x_train,x_test,y_train,y_test= train_test_split(X,Y,random_state=i,test_size=0.2)
    LR.fit(x_train,y_train)
    train_pred=LR.predict(x_train)
    test_pred=LR.predict(x_test)
    if round(r2_score(y_test,test_pred),2)==round(r2_score(y_train,train_pred),2):
        print("At random state ", i, "The model performance very well")
        print("At random state: ",i)
        print("Test R2 score is: ", round(r2_score(y_test,test_pred),2))
        print('Train R2 score is: ', round(r2_score(y_train,train_pred),2))
        print('*'*50,'\n')
# Out:
# At random state  54 The model performance very well
# At random state:  54
# Test R2 score is:  0.84
# Train R2 score is:  0.84
# **************************************************
#
# At random state  68 The model performance very well
# At random state:  68
# Test R2 score is:  0.83
# Train R2 score is:  0.83
# **************************************************

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
LR_model= LinearRegression()
RD_model= Ridge()
LS_model= Lasso()
DT_model= DecisionTreeRegressor()
SV_model= SVR()
KNR_model= KNeighborsRegressor()
RFR_model= RandomForestRegressor()

Elastic_model= ElasticNet()
SGH_model= SGDRegressor()
Bag_model=BaggingRegressor()
ADA_model=AdaBoostRegressor()
GB_model= GradientBoostingRegressor()

# %%
model=[LR_model,RD_model,LS_model,DT_model,SV_model,KNR_model,RFR_model,Elastic_model,SGH_model,Bag_model,ADA_model,GB_model ]

# %%
for m in model:
    m.fit(x_train,y_train)
    print('mean_absolute_error of ',m ,'model', mean_absolute_error(y_test,m.predict(x_test)))
    print('mean_square_error of',m,'model' , mean_squared_error(y_test,m.predict(x_test)))
    print('R2 Score of',m,'model', r2_score(y_test,m.predict(x_test) )*100)
    print('*' * 50, '\n\n')
# Out:
# mean_absolute_error of  LinearRegression() model 7.585883164661706
# mean_square_error of LinearRegression() model 69.42601092120032
# R2 Score of LinearRegression() model 43.82251307792288
# **************************************************
#
#
# mean_absolute_error of  Ridge() model 7.610034799284823
# mean_square_error of Ridge() model 66.07386778466616
# R2 Score of Ridge() model 46.534968751450165
# **************************************************
#
#
# mean_absolute_error of  Lasso() model 7.5572246551807325
# mean_square_error of Lasso() model 61.47234959146298
# R2 Score of Lasso() model 50.25838198937586
# **************************************************
#
#
# mean_absolute_error of  DecisionTreeRegressor() model 13.5
# mean_square_error of DecisionTreeRegressor() model 280.1666666666667
# R2 Score of DecisionTreeRegressor() model -126.70262980445042
# **************************************************
#
#
# mean_absolute_error of  SVR() model 9.451405487808266
# ...

# %% [markdown]
# # CROSS Validation

# %%
from sklearn.model_selection import cross_val_score
for i in model:
    print('mean_square of ',i, 'model',mean_squared_error(y_test,i.predict(x_test)))
    print("cross Validation score of ",i ," is ",cross_val_score(i,X,Y,cv=10, scoring='neg_mean_squared_error').mean())
    print('*'*50,'\n')
# Out:
# mean_square of  LinearRegression() model 69.42601092120032
# cross Validation score of  LinearRegression()  is  -71.08495560952339
# **************************************************
#
# mean_square of  Ridge() model 66.07386778466616
# cross Validation score of  Ridge()  is  -64.11289532679474
# **************************************************
#
# mean_square of  Lasso() model 61.47234959146298
# cross Validation score of  Lasso()  is  -48.80926727599116
# **************************************************
#
# mean_square of  DecisionTreeRegressor() model 280.1666666666667
# cross Validation score of  DecisionTreeRegressor()  is  -139.43333333333334
# **************************************************
#
# mean_square of  SVR() model 132.3982006190295
# cross Validation score of  SVR()  is  -103.07065860860291
# **************************************************
#
# mean_square of  KNeighborsRegressor() model 102.18000000000005
# ...

# %%
for i in model:
    print('Root mean_square of ',i, 'model',np.sqrt(mean_squared_error(y_test,i.predict(x_test))))
    score=cross_val_score(i,X,Y,cv=10, scoring='neg_mean_squared_error').mean()
    print("cross Validation score of root mean square ",i ," is ",np.sqrt(-score))
    print('*'*50,'\n')
# Out:
# Root mean_square of  LinearRegression() model 8.33222724853327
# cross Validation score of root mean square  LinearRegression()  is  8.431189454016758
# **************************************************
#
# Root mean_square of  Ridge() model 8.128583381172033
# cross Validation score of root mean square  Ridge()  is  8.007052849007227
# **************************************************
#
# Root mean_square of  Lasso() model 7.84043044682261
# cross Validation score of root mean square  Lasso()  is  6.986362950490846
# **************************************************
#
# Root mean_square of  DecisionTreeRegressor() model 16.738179909018385
# cross Validation score of root mean square  DecisionTreeRegressor()  is  10.44030650891055
# **************************************************
#
# Root mean_square of  SVR() model 11.506441701022498
# cross Validation score of root mean square  SVR()  is  10.152372068073692
# **************************************************
#
# ...
